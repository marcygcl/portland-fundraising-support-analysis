# %% [markdown]
# ### Linear Regression Analysis

# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import pearsonr, spearmanr


# Function to perform linear regression
def OLSlinearRegression(x_data, y_data, x_min, x_max, y_min, y_max, title, saveName = "", colors=[]):

    # Convert to numpy arrays
    x = np.asarray(x_data, dtype=np.float64)
    y = np.asarray(y_data, dtype=np.float64)

    # Fit regression model
    X = sm.add_constant(x)
    model = sm.OLS(y, X).fit()

    # Create a bunch of x values to use as points for your line of best fit
    x_plot = np.linspace(x_min, x_max, 300)
    X_plot = sm.add_constant(x_plot)

    # Predictions + confidence interval
    pred = model.get_prediction(X_plot)
    pred_summary = pred.summary_frame(alpha=0.05)

    y_pred = pred_summary['mean'].to_numpy(dtype=float)
    ci_lower = pred_summary['mean_ci_lower'].to_numpy(dtype=float)
    ci_upper = pred_summary['mean_ci_upper'].to_numpy(dtype=float)

    # R^2
    r_squared = model.rsquared
    print("R^2:", r_squared)

    # Make plot
    if len(colors) == 0:
        plt.scatter(x, y, label="Data", color="C0")
    else:
        for i in range(len(x)):
            plt.scatter(x[i], y[i], color=colors[i])


    # Plot regression line
    plt.plot(x_plot, y_pred, color='red', label="Fit")

    # Plot confidence interval
    plt.fill_between(
        x_plot,
        ci_lower,
        ci_upper,
        color='red',
        alpha=0.2,
        label="95% CI"
    )

    plt.xlabel("Something")
    plt.ylabel("Something Else")
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)

    if len(title) > 0:
        plt.title(title)

    # plt.legend()

    # Save + show
    plt.savefig(saveName, dpi=300)
    plt.show()

    return r_squared

# %% [markdown]
# ### Quick Test Cases

# %%
example_x = [1,2,3,4,5,9]
example_y = [1,2,3,4,5,9]

OLSlinearRegression(example_x, example_y, 0, 12, 0, 12, "Plot Title")
# Out:
# R^2: 1.0
# np.float64(1.0)

# %%
example_x = [1,2,3,4,5,9]
example_y = [1,5,3,2,5,10]

OLSlinearRegression(example_x, example_y, 0, 12, 0, 12, "Plot Title")
# Out:
# R^2: 0.7407467532467532
# np.float64(0.7407467532467532)

# %% [markdown]
# ### Real Data

# %%
all_data = pd.read_csv("./portland_data/ballot_and_contributions_data_2024.csv")

# %%
all_data
# Out:
#     year  district source_candidate_name  mentions  mention_share  \
# 0   2024         1           Timur Ender   16858.0       0.393226
# 1   2024         1        Terrence Hayes   15967.0       0.372443
# 2   2024         1         Loretta Smith   17984.0       0.419491
# 3   2024         1         Deian Salazar    5262.0       0.122740
# 4   2024         1            Noah Ernst   11606.0       0.270719
# ..   ...       ...                   ...       ...            ...
# 60  2024         4           Chris Henry    3199.0       0.041699
# 61  2024         4            Tony Morse   13246.0       0.172661
# 62  2024         4          Olivia Clark   45205.0       0.589244
# 63  2024         4            John Toran    8652.0       0.112778
# 64  2024         4           Ben Hufford   12275.0       0.160004
#
#     first_place_votes  first_place_share  total_ballot_weight  stv_threshold  \
# 0              3550.0           0.082807              42871.0        10718.0
# 1              3975.0           0.092720              42871.0        10718.0
# 2              5586.0           0.130298              42871.0        10718.0
# 3               720.0           0.016795              42871.0        10718.0
# 4              4052.0           0.094516              42871.0        10718.0
# ..                ...                ...                  ...            ...
# 60              301.0           0.003924              76717.0        19180.0
# 61             2004.0           0.026122              76717.0        19180.0
# 62            19138.0           0.249462              76717.0        19180.0
# 63             1052.0           0.013713              76717.0        19180.0
# 64             1694.0           0.022081              76717.0        19180.0
#
#     is_viable  ... contribution_count_mega contribution_share_micro  \
# 0        True  ...                       0                 0.666667
# 1        True  ...                       0                 0.776739
# 2        True  ...                       0                 0.553191
# 3       False  ...                       0                 0.759259
# 4        True  ...                       0                 0.810096
# ..        ...  ...                     ...                      ...
# 60      False  ...                       0                 0.976231
# 61      False  ...                       0                 0.534296
# 62       True  ...                       0                 0.431741
# 63      False  ...                       0                 0.909091
# 64      False  ...                       0                 0.457704
#
#    contribution_share_small  contribution_share_medium  \
# 0                  0.250000                   0.049206
# 1                  0.171340                   0.030114
# 2                  0.278530                   0.069632
# 3                  0.222222                   0.018519
# 4                  0.158654                   0.012019
# ..                      ...                        ...
# 60                 0.022071                   0.001698
# 61                 0.332130                   0.057762
# 62                 0.416382                   0.088737
# 63                 0.090909                   0.000000
# 64                 0.388218                   0.043807
#
#     contribution_share_large  contribution_share_mega  total_amount  \
# 0                   0.034127                      0.0      61809.84
# 1                   0.021807                      0.0      36108.05
# 2                   0.098646                      0.0      43744.96
# 3                   0.000000                      0.0       1380.00
# 4                   0.019231                      0.0      12993.18
# ..                       ...                      ...           ...
# 60                  0.000000                      0.0       5474.24
# 61                  0.075812                      0.0      41809.60
# 62                  0.063140                      0.0      95639.00
# 63                  0.000000                      0.0        180.00
# 64                  0.110272                      0.0      49074.17
#
#     total_contribution_count  average_contribution  median_contribution
# 0                       1260             49.055429                 20.0
# 1                        963             37.495379                 20.0
# 2                        517             84.613075                 25.0
# 3                         54             25.555556                 20.0
# 4                        416             31.233606                 20.0
# ..                       ...                   ...                  ...
# 60                       589              9.294126                  5.0
# 61                       554             75.468592                 25.0
# 62                      1172             81.603242                 50.0
# 63                        11             16.363636                 10.0
# 64                       662             74.130166                 26.0
#
# [65 rows x 37 columns]

# %%
all_data_3 = all_data[['candidate_key','mentions',
       'mention_share', 'first_place_votes', 'first_place_share',
       'total_ballot_weight', 'stv_threshold', 'is_viable','total_amount']]

#        'amount_micro', 'amount_small',
#        'amount_medium', 'amount_large', 'amount_mega', 'amount_share_micro',
#        'amount_share_small', 'amount_share_medium', 'amount_share_large',
#        'amount_share_mega', 'contribution_count_micro',
#        'contribution_count_small', 'contribution_count_medium',
#        'contribution_count_large', 'contribution_count_mega',
#        'contribution_share_micro', 'contribution_share_small',
#        'contribution_share_medium', 'contribution_share_large',
#        'contribution_share_mega', 'total_amount', 'total_contribution_count',
#        'average_contribution', 'median_contribution'

#I'm mostly leaving out contribution data until I get 2026 contribution data.

# %%
all_data_2 = pd.read_csv("./portland_data/2024_candidate_spending_profiles_city_council.csv")

# %% [markdown]
# ### Start by checking the data quality (spoiler: it's not great)

# %%
all_data[all_data['candidate_key'].isna()]
# Out:
# Empty DataFrame
# Columns: [year, district, source_candidate_name, mentions, mention_share, first_place_votes, first_place_share, total_ballot_weight, stv_threshold, is_viable, canonical_candidate_ballot, candidate_key, canonical_candidate_finance, amount_micro, amount_small, amount_medium, amount_large, amount_mega, amount_share_micro, amount_share_small, amount_share_medium, amount_share_large, amount_share_mega, contribution_count_micro, contribution_count_small, contribution_count_medium, contribution_count_large, contribution_count_mega, contribution_share_micro, contribution_share_small, contribution_share_medium, contribution_share_large, contribution_share_mega, total_amount, total_contribution_count, average_contribution, median_contribution]
# Index: []
#
# [0 rows x 37 columns]

# %%
all_data_2[all_data_2['candidate_key'].isna()]
# Out:
#     year  contest_type                 office  district  \
# 7   2024  city_council  Portland City Council         1
# 8   2024  city_council  Portland City Council         1
# 27  2024  city_council  Portland City Council         2
# 28  2024  city_council  Portland City Council         2
# 29  2024  city_council  Portland City Council         2
# 30  2024  city_council  Portland City Council         2
# 47  2024  city_council  Portland City Council         3
# 48  2024  city_council  Portland City Council         3
# 71  2024  city_council  Portland City Council         4
# 72  2024  city_council  Portland City Council         4
#
#                  profile_key  candidate  spending_amount_micro  \
# 7      2024|1|orestar|durphy     Durphy                1271.61
# 8    2024|1|orestar|mckenzie   McKenzie                 127.25
# 27    2024|2|orestar|burnell    Burnell                 100.31
# 28    2024|2|orestar|emerson    Emerson                 124.16
# 29  2024|2|orestar|middleton  Middleton                  88.84
# 30    2024|2|orestar|sherman    Sherman                 151.66
# 47      2024|3|orestar|morse      Morse                 769.15
# 48     2024|3|orestar|penson     Penson                 453.88
# 71     2024|4|orestar|kaluba     Kaluba                  11.38
# 72  2024|4|orestar|underdahl  Underdahl                  55.21
#
#     spending_amount_small  spending_amount_medium  spending_amount_large  ...  \
# 7                 3310.35                 8415.94               26454.38  ...
# 8                  235.54                 1309.47                3754.50  ...
# 27                 587.52                  440.00                2271.99  ...
# 28                 245.75                  115.00                1100.00  ...
# 29                 764.60                 2954.60                2835.37  ...
# 30                 543.16                 1722.62                1822.72  ...
# 47                2659.09                 1875.44               25728.15  ...
# 48                2749.42                 4666.73               23278.78  ...
# 71                   0.00                    0.00                 313.62  ...
# 72                 269.28                 1172.28                 390.00  ...
#
#     average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 7            284.494425              21.000             0.04         16300.00
# 8            139.147692              34.780             0.35           618.00
# 27           162.897419              55.000             0.70          1650.00
# 28            68.909130              14.850             0.79           750.00
# 29           114.541552              91.985             0.53           694.00
# 30            78.521481              23.830             0.53           442.72
# 47           472.609709              55.000             1.58         22863.25
# 48           808.487472             161.695             2.10         14173.09
# 71           108.333333              10.680             0.70           313.62
# 72            82.033478              40.570             0.18           390.00
#
#     std_expenditure  source_file_stem  source_candidate_name  \
# 7       1026.683289            Durphy                 Durphy
# 8        203.240027          McKenzie               McKenzie
# 27       344.556904           Burnell                Burnell
# 28       165.297797           Emerson                Emerson
# 29       137.808240         Middleton              Middleton
# 30       111.592044           Sherman                Sherman
# 47      1854.397059             Morse                  Morse
# 48      1802.183999            Penson                 Penson
# 71       177.853484            Kaluba                 Kaluba
# 72       100.408038         Underdahl              Underdahl
#
#     canonical_candidate  candidate_key              linkage_status
# 7                   NaN            NaN  unmatched_source_candidate
# 8                   NaN            NaN  unmatched_source_candidate
# 27                  NaN            NaN  unmatched_source_candidate
# 28                  NaN            NaN  unmatched_source_candidate
# 29                  NaN            NaN  unmatched_source_candidate
# 30                  NaN            NaN  unmatched_source_candidate
# 47                  NaN            NaN  unmatched_source_candidate
# 48                  NaN            NaN  unmatched_source_candidate
# 71                  NaN            NaN  unmatched_source_candidate
# 72                  NaN            NaN  unmatched_source_candidate
#
# [10 rows x 38 columns]

# %% [markdown]
# ### Ok, this might be a problem, 10 of these names do not match real candidates, at least one due to human error

# %%
#I'm gonna just try and figure these out by hand, since there's only 10 of them. Here are my findings, code is immediately below:

#District 1:
# "Durphy" has gotta be Jamie Dunphy, 
# "McKenzie" dropped out, and is thus not in the ballot data, 
# And then we're missing spending data on Doug Clove, but he has donations, so it must exist (it's possible orestar just doens't have it, but that seems unlikely).   

# District 2:
# Dan Ryan had lots of donations (and won a seat!) and is missing from spending 
# There's 4 extra candidates in spending, all withdrew according to the wiki 

# District 3:
#These 3 were on the ballot, but we don't have spending data: ['Dan Gilk', 'Matthew (Matt) Anderson', 'Rex Burkholder']
#I might buy that Matt didn't spend anything (only raised $700, but Gilk was like $3500, and Rex was 5 figures)

#And then as far as spending data: 
#Penson was on the ballot in district 2?? 
#Morse was on the ballot in district 4? 
#Kezia got 6% of FPV, wiki thinks Brian Conley, Daniel DeMelo, and Patrick Hilton were all on the ballot too. 
#It's possible the site we're scraping didn't bother to list really minor candidates, but Kezia was the 4th place FPV, she really should be there.

#District 4
#Andra Vltavin - on the ballot, no spending data (only raised $800, might be fine)

#'Bob Callahan', 'Chloe Mason', 'Ciatta R Thompson' - all on the ballot, but not in our mentions/FPV data 
#'Jeremy Beausoleil Smith', 'Kaluba', and 'Underdahl' withdrew, so that's fine

# %%
dist = 1
ballot_list = all_data[all_data['district'] == dist]['source_candidate_name']
spending_list = all_data_2[all_data_2['district'] == dist]['candidate']

print([x for x in ballot_list if x not in set(spending_list)])
print([x for x in spending_list if x not in set(ballot_list)])
# Out:
# ['Jamie Dunphy', 'Doug Clove']
# ['Durphy', 'McKenzie']

# %%
all_data[all_data['district'] == 1].sort_values("source_candidate_name")  #note: all_data gets overwritten in a merge a few lines down, so if you want to change this, run it from the beginning again
# Out:
#     year  district source_candidate_name  mentions  mention_share  \
# 11  2024         1        Candace Avalos   22267.0       0.519395
# 8   2024         1            Cayle Tern    9061.0       0.211355
# 12  2024         1            David Linn    9324.0       0.217490
# 3   2024         1         Deian Salazar    5262.0       0.122740
# 6   2024         1            Doug Clove    7593.0       0.177113
# 5   2024         1          Jamie Dunphy   18470.0       0.430827
# 7   2024         1              Joe Furi    4070.0       0.094936
# 2   2024         1         Loretta Smith   17984.0       0.419491
# 4   2024         1            Noah Ernst   11606.0       0.270719
# 10  2024         1           Steph Routh   20440.0       0.476779
# 1   2024         1        Terrence Hayes   15967.0       0.372443
# 9   2024         1        Thomas Shervey    3507.0       0.081804
# 0   2024         1           Timur Ender   16858.0       0.393226
#
#     first_place_votes  first_place_share  total_ballot_weight  stv_threshold  \
# 11             8297.0           0.193534              42871.0        10718.0
# 8               711.0           0.016585              42871.0        10718.0
# 12             1111.0           0.025915              42871.0        10718.0
# 3               720.0           0.016795              42871.0        10718.0
# 6              1698.0           0.039607              42871.0        10718.0
# 5              5064.0           0.118122              42871.0        10718.0
# 7               355.0           0.008281              42871.0        10718.0
# 2              5586.0           0.130298              42871.0        10718.0
# 4              4052.0           0.094516              42871.0        10718.0
# 10             3894.0           0.090831              42871.0        10718.0
# 1              3975.0           0.092720              42871.0        10718.0
# 9               385.0           0.008980              42871.0        10718.0
# 0              3550.0           0.082807              42871.0        10718.0
#
#     is_viable  ... contribution_count_mega contribution_share_micro  \
# 11       True  ...                       2                 0.723561
# 8       False  ...                       0                 0.833866
# 12      False  ...                       0                 0.700000
# 3       False  ...                       0                 0.759259
# 6       False  ...                       0                 0.615385
# 5        True  ...                       1                 0.815166
# 7       False  ...                       0                 0.363636
# 2        True  ...                       0                 0.553191
# 4        True  ...                       0                 0.810096
# 10       True  ...                       0                 0.720000
# 1        True  ...                       0                 0.776739
# 9       False  ...                       0                 0.523810
# 0        True  ...                       0                 0.666667
#
#    contribution_share_small  contribution_share_medium  \
# 11                 0.236278                   0.022088
# 8                  0.153355                   0.009585
# 12                 0.261538                   0.030769
# 3                  0.222222                   0.018519
# 6                  0.153846                   0.076923
# 5                  0.143128                   0.020853
# 7                  0.545455                   0.000000
# 2                  0.278530                   0.069632
# 4                  0.158654                   0.012019
# 10                 0.238481                   0.025823
# 1                  0.171340                   0.030114
# 9                  0.428571                   0.047619
# 0                  0.250000                   0.049206
#
#     contribution_share_large  contribution_share_mega  total_amount  \
# 11                  0.016734                 0.001339      58893.80
# 8                   0.003195                 0.000000       7395.00
# 12                  0.007692                 0.000000       4776.99
# 3                   0.000000                 0.000000       1380.00
# 6                   0.153846                 0.000000       1505.00
# 5                   0.019905                 0.000948      35174.53
# 7                   0.090909                 0.000000        813.95
# 2                   0.098646                 0.000000      43744.96
# 4                   0.019231                 0.000000      12993.18
# 10                  0.015696                 0.000000      76006.71
# 1                   0.021807                 0.000000      36108.05
# 9                   0.000000                 0.000000       1060.00
# 0                   0.034127                 0.000000      61809.84
#
#     total_contribution_count  average_contribution  median_contribution
# 11                      1494             39.420214                20.00
# 8                        313             23.626198                10.00
# 12                       130             36.746077                20.00
# 3                         54             25.555556                20.00
# 6                         13            115.769231                20.00
# 5                       1055             33.340787                10.00
# 7                         11             73.995455                31.86
# 2                        517             84.613075                25.00
# 4                        416             31.233606                20.00
# 10                      1975             38.484410                20.24
# 1                        963             37.495379                20.00
# 9                         21             50.476190                25.00
# 0                       1260             49.055429                20.00
#
# [13 rows x 37 columns]

# %%
all_data_2[all_data_2['district'] == 1].sort_values("candidate")
# Out:
#     year  contest_type                 office  district  \
# 0   2024  city_council  Portland City Council         1
# 1   2024  city_council  Portland City Council         1
# 2   2024  city_council  Portland City Council         1
# 3   2024  city_council  Portland City Council         1
# 7   2024  city_council  Portland City Council         1
# 4   2024  city_council  Portland City Council         1
# 5   2024  city_council  Portland City Council         1
# 8   2024  city_council  Portland City Council         1
# 6   2024  city_council  Portland City Council         1
# 9   2024  city_council  Portland City Council         1
# 10  2024  city_council  Portland City Council         1
# 11  2024  city_council  Portland City Council         1
# 12  2024  city_council  Portland City Council         1
#
#                 profile_key       candidate  spending_amount_micro  \
# 0     2024|1|candace avalos  Candace Avalos                1353.50
# 1         2024|1|cayle tern      Cayle Tern                 195.10
# 2         2024|1|david linn      David Linn                 415.06
# 3      2024|1|deian salazar   Deian Salazar                 404.30
# 7     2024|1|orestar|durphy          Durphy                1271.61
# 4           2024|1|joe furi        Joe Furi                  26.25
# 5      2024|1|loretta smith   Loretta Smith                4035.24
# 8   2024|1|orestar|mckenzie        McKenzie                 127.25
# 6         2024|1|noah ernst      Noah Ernst                 145.73
# 9        2024|1|steph routh     Steph Routh                1885.16
# 10    2024|1|terrence hayes  Terrence Hayes                 778.85
# 11    2024|1|thomas shervey  Thomas Shervey                  66.93
# 12       2024|1|timur ender     Timur Ender                 324.39
#
#     spending_amount_small  spending_amount_medium  spending_amount_large  ...  \
# 0                 7027.16                12667.39               51604.78  ...
# 1                 1104.67                 1627.98               10274.96  ...
# 2                  278.93                 1540.00                2942.50  ...
# 3                  829.16                 1845.20                1055.76  ...
# 7                 3310.35                 8415.94               26454.38  ...
# 4                  110.00                  283.75                 330.00  ...
# 5                23590.11                53752.79              134672.06  ...
# 8                  235.54                 1309.47                3754.50  ...
# 6                 1723.32                 4387.51               22879.63  ...
# 9                 4531.86                 5169.86               23150.81  ...
# 10                2966.43                 4473.90               21800.63  ...
# 11                 466.45                  115.00                1575.60  ...
# 12                2299.52                 1294.37               20787.16  ...
#
#     average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 0            377.067936              78.260             0.08         21297.66
# 1            183.370972              80.000             0.18           868.60
# 2             78.431667              15.990             0.18           750.00
# 3             70.090132              20.825             0.18          1192.43
# 7            284.494425              21.000             0.04         16300.00
# 4             93.750000              55.000             3.50           330.00
# 5            969.629940             100.895             0.07         48200.00
# 8            139.147692              34.780             0.35           618.00
# 6            441.382794             195.000             0.18         10200.00
# 9            352.813584               8.720             0.20         31881.49
# 10           470.183401              68.780             0.87          8000.00
# 11            88.959200              14.990             0.20           945.60
# 12           985.265125             184.870             0.24         13098.42
#
#     std_expenditure  source_file_stem  source_candidate_name  \
# 0       1364.949484            Avalos                 Avalos
# 1        243.060876              Tern                   Tern
# 2        153.081951              Linn                   Linn
# 3        154.362181           Salazar                Salazar
# 7       1026.683289            Durphy                 Durphy
# 4        111.281577              Furi                   Furi
# 5       3599.745502             Smith                  Smith
# 8        203.240027          McKenzie               McKenzie
# 6       1113.966186             Ernst                  Ernst
# 9       1821.093465             Routh                  Routh
# 10      1132.049040             Hayes                  Hayes
# 11       197.706127           Shervey                Shervey
# 12      1835.055606             Ender                  Ender
#
#     canonical_candidate          candidate_key                 linkage_status
# 0        Candace Avalos  2024|1|candace avalos  matched_to_official_candidate
# 1            Cayle Tern      2024|1|cayle tern  matched_to_official_candidate
# 2            David Linn      2024|1|david linn  matched_to_official_candidate
# 3         Deian Salazar   2024|1|deian salazar  matched_to_official_candidate
# 7                   NaN                    NaN     unmatched_source_candidate
# 4              Joe Furi        2024|1|joe furi  matched_to_official_candidate
# 5         Loretta Smith   2024|1|loretta smith  matched_to_official_candidate
# 8                   NaN                    NaN     unmatched_source_candidate
# 6            Noah Ernst      2024|1|noah ernst  matched_to_official_candidate
# 9           Steph Routh     2024|1|steph routh  matched_to_official_candidate
# 10       Terrence Hayes  2024|1|terrence hayes  matched_to_official_candidate
# 11       Thomas Shervey  2024|1|thomas shervey  matched_to_official_candidate
# 12          Timur Ender     2024|1|timur ender  matched_to_official_candidate
#
# [13 rows x 38 columns]

# %%
#I'll also note that 3 candidates in district 1 were on the ballot, and do not appear in EITHER data set:

#Michael (Mike) Sands
#Joe Allen 
#Peggy Sue Owens

#None of them are viable, but this is very incomplete data.

# %% [markdown]
# ### Nevertheless, let's keep going:
#
# Some other odities show up in the data we do have:
#
# Loretta Smith is recorded as having spent $1.46 million on her campaign. Could be legit, but that's very high.
# Steve Novick spent $1 million. Also high. No one else spent more than $310K.
#
# Only one candidate spent less than they recieved according to this data, which is a bigger sign to me that something is wrong here.

# %%
# all_data = pd.merge(all_data_3, all_data_2, on = 'candidate_key', how='left')   
all_data = pd.merge(all_data_3, all_data_2, on = 'candidate_key', how='inner')      #I've chosen an inner merge to exclude any candidate we don't have both data sets for

# %%
all_data_2['calculated_total_spending'] = all_data_2[['spending_amount_micro', 'spending_amount_small',
       'spending_amount_medium', 'spending_amount_large',
       'spending_amount_mega']].sum(axis=1)

all_data_2[all_data_2['district'] == 1][['candidate','total_spending','calculated_total_spending','spending_amount_micro', 'spending_amount_small',
       'spending_amount_medium', 'spending_amount_large',
       'spending_amount_mega']]
# Out:
#          candidate  total_spending  calculated_total_spending  \
# 0   Candace Avalos       177221.93                  177221.93
# 1       Cayle Tern        13202.71                   13202.71
# 2       David Linn         5176.49                    5176.49
# 3    Deian Salazar         5326.85                    5326.85
# 4         Joe Furi          750.00                     750.00
# 5    Loretta Smith      1464141.21                 1464141.21
# 6       Noah Ernst        60028.06                   60028.06
# 7           Durphy       111237.32                  111237.32
# 8         McKenzie         5426.76                    5426.76
# 9      Steph Routh       201809.37                  201809.37
# 10  Terrence Hayes        92626.13                   92626.13
# 11  Thomas Shervey         2223.98                    2223.98
# 12     Timur Ender       157642.42                  157642.42
#
#     spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 0                 1353.50                7027.16                12667.39
# 1                  195.10                1104.67                 1627.98
# 2                  415.06                 278.93                 1540.00
# 3                  404.30                 829.16                 1845.20
# 4                   26.25                 110.00                  283.75
# 5                 4035.24               23590.11                53752.79
# 6                  145.73                1723.32                 4387.51
# 7                 1271.61                3310.35                 8415.94
# 8                  127.25                 235.54                 1309.47
# 9                 1885.16                4531.86                 5169.86
# 10                 778.85                2966.43                 4473.90
# 11                  66.93                 466.45                  115.00
# 12                 324.39                2299.52                 1294.37
#
#     spending_amount_large  spending_amount_mega
# 0                51604.78             104569.10
# 1                10274.96                  0.00
# 2                 2942.50                  0.00
# 3                 1055.76               1192.43
# 4                  330.00                  0.00
# 5               134672.06            1248091.01
# 6                22879.63              30891.87
# 7                26454.38              71785.04
# 8                 3754.50                  0.00
# 9                23150.81             167071.68
# 10               21800.63              62606.32
# 11                1575.60                  0.00
# 12               20787.16             132936.98

# %%
all_data[['candidate_key','total_amount','total_spending']]
# Out:
#                    candidate_key  total_amount  total_spending
# 0             2024|1|timur ender      61809.84       157642.42
# 1          2024|1|terrence hayes      36108.05        92626.13
# 2           2024|1|loretta smith      43744.96      1464141.21
# 3           2024|1|deian salazar       1380.00         5326.85
# 4              2024|1|noah ernst      12993.18        60028.06
# 5                2024|1|joe furi        813.95          750.00
# 6              2024|1|cayle tern       7395.00        13202.71
# 7          2024|1|thomas shervey       1060.00         2223.98
# 8             2024|1|steph routh      76006.71       201809.37
# 9          2024|1|candace avalos      58893.80       177221.93
# 10             2024|1|david linn       4776.99         5176.49
# 11            2024|2|chris olson       7272.45        42466.85
# 12              2024|2|sam sachs       4349.01         5480.68
# 13         2024|2|debbie kitchin      34884.88        70605.48
# 14           2024|2|laura streib      10718.42        30462.27
# 15        2024|2|marnie glickman      34318.00       133462.97
# 16               2024|2|nat west      51915.64       131140.06
# 17    2024|2|elana pirtle guiney      47039.93        85457.75
# 18        2024|2|james armstrong      25246.18        63784.29
# 19  2024|2|michael mike marshall      55074.82       100931.24
# 20          2024|2|jennifer park      15950.86        45905.09
# 21           2024|2|will mespelt       1215.00        16523.17
# 22          2024|2|mariah hudson      74201.68       154825.11
# 23           2024|2|sameer kanal      34711.76       102966.45
# 24         2024|2|nabil zaghloul      26484.00       109719.75
# 25             2024|2|bob simril      26230.00        80881.96
# 26        2024|2|jonathan tasini      49453.07       106663.61
# 27         2024|2|tiffani penson      80381.24       143910.77
# 28        2024|2|michelle depass      32578.29       121536.89
# 29          2024|2|reuben berlin       6309.98         9124.48
# 30       2024|3|angelita morillo      64641.17       230589.39
# 31          2024|3|ahlam k osman       9002.06        45930.68
# 32           2024|3|steve novick      87240.55      1081644.06
# 33          2024|3|harrison kass      16057.89        60367.86
# 34               2024|3|luke zak       9730.62        40457.04
# 35          2024|3|chris flanary      17826.94        56362.95
# 36    2024|3|jonathan jon walker       3842.50         4611.13
# 37    2024|3|tiffany koyama lane      88689.62       308922.62
# 38         2024|3|kelly janes kj       4730.00         9301.96
# 39    2024|3|theo hathaway saner       7504.99        12588.82
# 40          2024|3|jesse cornett      52912.46       140392.04
# 41          2024|3|philippe knab       5115.00         5919.57
# 42            2024|4|mitch green      60464.56       197062.06
# 43          2024|4|mike dinapoli       7289.00         7389.00
# 44             2024|4|moses ross      27896.63       110289.04
# 45        2024|4|michael trimble        509.00         1349.86
# 46         2024|4|stanley penkin      61847.00       105363.28
# 47             2024|4|eli arnold      50778.15       108592.89
# 48            2024|4|chad lykins      47007.66       127926.92
# 49         2024|4|eric zimmerman      41878.55       291095.65
# 50           2024|4|sarah silkie      25477.64       102010.01
# 51           2024|4|lisa freeman      25827.58        66943.08
# 52          2024|4|bob weinstein      33919.91        80985.14
# 53            2024|4|chris henry       5474.24        28935.93
# 54             2024|4|tony morse      41809.60        81288.87
# 55           2024|4|olivia clark      95639.00       194106.54
# 56             2024|4|john toran        180.00        16332.26
# 57            2024|4|ben hufford      49074.17        89305.67

# %%
all_data[['candidate_key','total_amount','total_spending']][all_data['total_amount'] > all_data['total_spending']]
# Out:
#      candidate_key  total_amount  total_spending
# 5  2024|1|joe furi        813.95           750.0

# %%
all_data[['candidate_key','total_amount','total_spending']][all_data['total_spending'] > 300_000]
# Out:
#                  candidate_key  total_amount  total_spending
# 2         2024|1|loretta smith      43744.96      1464141.21
# 32         2024|3|steve novick      87240.55      1081644.06
# 37  2024|3|tiffany koyama lane      88689.62       308922.62

# %%
all_data[all_data['district'] == 1][['mention_share', 'first_place_share']].sum()
# Out:
# mention_share        3.180378
# first_place_share    0.761261
# dtype: float64

# %%
#Candidates rank up to 6, so that tally at least is fine, knowing we're missing major candidates.

# %% [markdown]
# ### So we need to look into the data sources more, but again, let's keep going so we have the whole pipeline ready.

# %% [markdown]
# ### Analysis

# %%
save_dir = './portland_reg_figures/'

# %%
# all_data = all_data.fillna(0)    #ideally we don't need this, I think the Nans only come from other errors that need to be corrected/removed, not zeroed out.

# %%
# independent_vars = all_data.columns[13:]
independent_vars = all_data.columns[15:-4]                  #define all the independent variables (financial)
dependent_vars = ['mention_share','first_place_share']      #define all the dependent variables (election performance metrics)

#Dictionaries!
r2_values = {}
pearsons = {}
spearmans = {}
pearsons_p_value = {}
spearmans_p_value = {}

#Does a regression for each independant variable's relationship with each dependent variable 
for y_name in dependent_vars:
    y_data = list(all_data[y_name])
    r2_values[y_name] = []
    pearsons[y_name] = []
    spearmans[y_name] = []
    pearsons_p_value[y_name] = []
    spearmans_p_value[y_name] = []
    for x_name in independent_vars:
        x_data = list(all_data[x_name])
        x_min = min(0, min(x_data))  #don't think any of these variables are negative, but just to be safe 
        x_max = max(x_data) * 1.2
        y_min = -0.05
        y_max = 1.05
        title = y_name + " vs " + x_name 
        print("\n" + title + ":\n")

        # print("Debug:", x_data, y_data)
        r2_values[y_name].append(OLSlinearRegression(x_data, y_data, x_min, x_max, y_min, y_max, title, saveName = save_dir + title, colors=[]))   #linear regression 

        pearson_corr, pearson_p = pearsonr(x_data, y_data)     #pearson coefficients + p value
        spearman_corr, spearman_p = spearmanr(x_data, y_data)  #spearman coefficients + p value

        pearsons[y_name].append(pearson_corr)
        spearmans[y_name].append(spearman_corr)
        pearsons_p_value[y_name].append(pearson_p)
        spearmans_p_value[y_name].append(spearman_p)

#summarize it all as a data frame
data_summary = pd.DataFrame({
    "variable": independent_vars,
    "mentions r2": r2_values[dependent_vars[0]], 
    "mentions pearson": pearsons[dependent_vars[0]], 
    "mentions pearson p value": pearsons_p_value[dependent_vars[0]],
    "mentions spearman": spearmans[dependent_vars[0]], 
    "mentions spearman p value": spearmans_p_value[dependent_vars[0]],
    "FPV r2": r2_values[dependent_vars[1]], 
    "FPV pearson": pearsons[dependent_vars[1]], 
    "FPV spearman": spearmans[dependent_vars[1]],
    "FPV spearman": spearmans[dependent_vars[1]], 
    "FPV spearman p value": spearmans_p_value[dependent_vars[1]]
})
# Out:
# mention_share vs spending_amount_micro:
#
# R^2: 0.21301298489060716
# mention_share vs spending_amount_small:
#
# R^2: 0.298729478779877
# mention_share vs spending_amount_medium:
#
# R^2: 0.16884560693976236
# mention_share vs spending_amount_large:
#
# R^2: 0.29950628560332804
# mention_share vs spending_amount_mega:
#
# R^2: 0.24387978871763327
# mention_share vs spending_amount_share_micro:
#
# R^2: 0.15388043015107722
# mention_share vs spending_amount_share_small:
#
# R^2: 0.15720048450170765
# mention_share vs spending_amount_share_medium:
#
# R^2: 0.1921958758177733
# mention_share vs spending_amount_share_large:
#
# R^2: 0.25126151659012996
# mention_share vs spending_amount_share_mega:
#
# R^2: 0.31129530683149564
# mention_share vs spending_count_micro:
#
# R^2: 0.22091935809167806
# mention_share vs spending_count_small:
#
# R^2: 0.3055105037085699
# mention_share vs spending_count_medium:
#
# R^2: 0.1747452631012667
# mention_share vs spending_count_large:
#
# R^2: 0.25604160522520847
# mention_share vs spending_count_mega:
#
# R^2: 0.3756507013448962
# mention_share vs spending_count_share_micro:
#
# R^2: 0.11076518893432696
# mention_share vs spending_count_share_small:
#
# R^2: 0.03343082965713162
# mention_share vs spending_count_share_medium:
#
# R^2: 0.0004305757649253339
# mention_share vs spending_count_share_large:
#
# R^2: 5.167823537033378e-05
# mention_share vs spending_count_share_mega:
#
# R^2: 0.28649832022989485
# mention_share vs total_spending:
#
# R^2: 0.2538150162310969
# mention_share vs expenditure_count:
#
# R^2: 0.3144815338525899
# mention_share vs average_expenditure:
#
# R^2: 0.29660181061703095
# mention_share vs median_expenditure:
#
# R^2: 0.03222797504034003
# mention_share vs min_expenditure:
#
# R^2: 0.03436878466509952
# mention_share vs max_expenditure:
#
# R^2: 0.44321957868947925
# mention_share vs std_expenditure:
#
# R^2: 0.347577050740573
# first_place_share vs spending_amount_micro:
#
# R^2: 0.2222891083228703
# first_place_share vs spending_amount_small:
#
# R^2: 0.3487763208497138
# first_place_share vs spending_amount_medium:
#
# R^2: 0.1923501059892846
# first_place_share vs spending_amount_large:
#
# R^2: 0.3217202695701469
# first_place_share vs spending_amount_mega:
#
# R^2: 0.2959469506410385
# first_place_share vs spending_amount_share_micro:
#
# R^2: 0.11467657822044641
# first_place_share vs spending_amount_share_small:
#
# R^2: 0.09839270292629576
# first_place_share vs spending_amount_share_medium:
#
# R^2: 0.1366699015884989
# first_place_share vs spending_amount_share_large:
#
# R^2: 0.19673647741060096
# first_place_share vs spending_amount_share_mega:
#
# R^2: 0.2306475663605415
# first_place_share vs spending_count_micro:
#
# R^2: 0.22383507439976102
# first_place_share vs spending_count_small:
#
# R^2: 0.3468650527159878
# first_place_share vs spending_count_medium:
#
# R^2: 0.19685758018662958
# first_place_share vs spending_count_large:
#
# R^2: 0.2721537959544331
# first_place_share vs spending_count_mega:
#
# R^2: 0.4074423362526155
# first_place_share vs spending_count_share_micro:
#
# R^2: 0.09664959133123863
# first_place_share vs spending_count_share_small:
#
# R^2: 0.05216414475692355
# first_place_share vs spending_count_share_medium:
#
# R^2: 8.29445975993881e-05
# first_place_share vs spending_count_share_large:
#
# R^2: 0.000700486601004191
# first_place_share vs spending_count_share_mega:
#
# R^2: 0.20675569853524434
# first_place_share vs total_spending:
#
# R^2: 0.303719981884202
# first_place_share vs expenditure_count:
#
# R^2: 0.3387449699619599
# first_place_share vs average_expenditure:
#
# R^2: 0.2627614326710801
# first_place_share vs median_expenditure:
#
# R^2: 0.022695464420276812
# first_place_share vs min_expenditure:
#
# R^2: 0.016628768176019437
# first_place_share vs max_expenditure:
#
# R^2: 0.4504890070804758
# first_place_share vs std_expenditure:
#
# R^2: 0.34202781241292934

# %%
data_summary
# Out:
#                         variable  mentions r2  mentions pearson  \
# 0          spending_amount_micro     0.213013          0.461533
# 1          spending_amount_small     0.298729          0.546562
# 2         spending_amount_medium     0.168846          0.410908
# 3          spending_amount_large     0.299506          0.547272
# 4           spending_amount_mega     0.243880          0.493842
# 5    spending_amount_share_micro     0.153880         -0.392276
# 6    spending_amount_share_small     0.157200         -0.396485
# 7   spending_amount_share_medium     0.192196         -0.438402
# 8    spending_amount_share_large     0.251262         -0.501260
# 9     spending_amount_share_mega     0.311295          0.557938
# 10          spending_count_micro     0.220919          0.470021
# 11          spending_count_small     0.305511          0.552730
# 12         spending_count_medium     0.174745          0.418025
# 13          spending_count_large     0.256042          0.506006
# 14           spending_count_mega     0.375651          0.612904
# 15    spending_count_share_micro     0.110765         -0.332814
# 16    spending_count_share_small     0.033431          0.182841
# 17   spending_count_share_medium     0.000431         -0.020750
# 18    spending_count_share_large     0.000052         -0.007189
# 19     spending_count_share_mega     0.286498          0.535255
# 20                total_spending     0.253815          0.503801
# 21             expenditure_count     0.314482          0.560787
# 22           average_expenditure     0.296602          0.544612
# 23            median_expenditure     0.032228          0.179522
# 24               min_expenditure     0.034369         -0.185388
# 25               max_expenditure     0.443220          0.665747
# 26               std_expenditure     0.347577          0.589557
#
#     mentions pearson p value  mentions spearman  mentions spearman p value  \
# 0               2.657469e-04           0.503768               5.547487e-05
# 1               9.056087e-06           0.678489               4.843707e-09
# 2               1.355047e-03           0.643791               4.995576e-08
# 3               8.769082e-06           0.697868               1.141232e-09
# 4               8.167237e-05           0.774171               1.023023e-12
# 5               2.322660e-03          -0.524439               2.383010e-05
# 6               2.061948e-03          -0.447168               4.329723e-04
# 7               5.772154e-04          -0.474607               1.672038e-04
# 8               6.123970e-05          -0.548187               8.411761e-06
# 9               5.357745e-06           0.583208               1.553745e-06
# 10              1.971329e-04           0.446732               4.393014e-04
# 11              6.829379e-06           0.675148               6.146722e-09
# 12              1.093902e-03           0.655912               2.287846e-08
# 13              5.075898e-05           0.657866               2.010616e-08
# 14              3.153582e-07           0.779118               5.912837e-13
# 15              1.068960e-02          -0.421521               9.830465e-04
# 16              1.695114e-01           0.170014               2.019846e-01
# 17              8.771318e-01           0.018734               8.889925e-01
# 18              9.572883e-01           0.051371               7.017437e-01
# 19              1.497548e-05           0.556535               5.722186e-06
# 20              5.540383e-05           0.798271               6.152257e-14
# 21              4.683712e-06           0.676983               5.395085e-09
# 22              9.889611e-06           0.550586               7.538006e-06
# 23              1.775243e-01           0.343697               8.253085e-03
# 24              1.635441e-01          -0.229107               8.364162e-02
# 25              1.182466e-08           0.683474               3.374915e-09
# 26              1.119700e-06           0.577902               2.032433e-06
#
#       FPV r2  FPV pearson  FPV spearman  FPV spearman p value
# 0   0.222289     0.471475      0.496816          7.282541e-05
# 1   0.348776     0.590573      0.665139          1.232627e-08
# 2   0.192350     0.438577      0.626073          1.473303e-07
# 3   0.321720     0.567204      0.698668          1.072515e-09
# 4   0.295947     0.544010      0.762406          3.571575e-12
# 5   0.114677    -0.338639     -0.534283          1.562449e-05
# 6   0.098393    -0.313676     -0.451106          3.795575e-04
# 7   0.136670    -0.369689     -0.473930          1.713411e-04
# 8   0.196736    -0.443550     -0.519149          2.973929e-05
# 9   0.230648     0.480258      0.553886          6.473557e-06
# 10  0.223835     0.473112      0.414640          1.211879e-03
# 11  0.346865     0.588953      0.662441          1.480224e-08
# 12  0.196858     0.443686      0.638764          6.837596e-08
# 13  0.272154     0.521684      0.654850          2.453336e-08
# 14  0.407442     0.638312      0.770242          1.565929e-12
# 15  0.096650    -0.310885     -0.451913          3.693823e-04
# 16  0.052164     0.228395      0.151373          2.566766e-01
# 17  0.000083    -0.009107      0.011536          9.315117e-01
# 18  0.000700    -0.026467      0.075180          5.748744e-01
# 19  0.206756     0.454704      0.563311          4.153183e-06
# 20  0.303720     0.551108      0.780553          5.030230e-13
# 21  0.338745     0.582018      0.669538          9.108501e-09
# 22  0.262761     0.512603      0.555877          5.900844e-06
# 23  0.022695     0.150650      0.358988          5.651328e-03
# 24  0.016629    -0.128953     -0.176668          1.846291e-01
# 25  0.450489     0.671185      0.662831          1.441703e-08
# 26  0.342028     0.584831      0.558030          5.334720e-06

# %%
#With color!
data_summary.style.background_gradient(subset=["mentions r2"], cmap="Blues").background_gradient(subset=["FPV r2"], cmap="Greens")
# Out:
# <style type="text/css">
# #T_46479_row0_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_46479_row0_col6 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_46479_row1_col1, #T_46479_row3_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_46479_row1_col6 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_46479_row2_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_46479_row2_col6 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_46479_row3_col6 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_46479_row4_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_46479_row4_col6 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_46479_row5_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_46479_row5_col6 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_46479_row6_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_46479_row6_col6 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_46479_row7_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_46479_row7_col6 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_46479_row8_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_46479_row8_col6, #T_46479_row12_col6 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_46479_row9_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_46479_row9_col6 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_46479_row10_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_46479_row10_col6 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_46479_row11_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_46479_row11_col6 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_46479_row12_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_46479_row13_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_46479_row13_col6 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_46479_row14_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_46479_row14_col6 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_46479_row15_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_46479_row15_col6 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_46479_row16_col1, #T_46479_row24_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_46479_row16_col6 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_46479_row17_col1, #T_46479_row18_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_46479_row17_col6, #T_46479_row18_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_46479_row19_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_46479_row19_col6 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_46479_row20_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_46479_row20_col6 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_46479_row21_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_46479_row21_col6 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_46479_row22_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_46479_row22_col6 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_46479_row23_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_46479_row23_col6 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_46479_row24_col6 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_46479_row25_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_46479_row25_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_46479_row26_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_46479_row26_col6 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_46479">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46479_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_46479_level0_col1" class="col_heading level0 col1" >mentions r2</th>
#       <th id="T_46479_level0_col2" class="col_heading level0 col2" >mentions pearson</th>
#       <th id="T_46479_level0_col3" class="col_heading level0 col3" >mentions pearson p value</th>
#       <th id="T_46479_level0_col4" class="col_heading level0 col4" >mentions spearman</th>
#       <th id="T_46479_level0_col5" class="col_heading level0 col5" >mentions spearman p value</th>
#       <th id="T_46479_level0_col6" class="col_heading level0 col6" >FPV r2</th>
#       <th id="T_46479_level0_col7" class="col_heading level0 col7" >FPV pearson</th>
#       <th id="T_46479_level0_col8" class="col_heading level0 col8" >FPV spearman</th>
#       <th id="T_46479_level0_col9" class="col_heading level0 col9" >FPV spearman p value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46479_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46479_row0_col0" class="data row0 col0" >spending_amount_micro</td>
#       <td id="T_46479_row0_col1" class="data row0 col1" >0.213013</td>
#       <td id="T_46479_row0_col2" class="data row0 col2" >0.461533</td>
#       <td id="T_46479_row0_col3" class="data row0 col3" >0.000266</td>
#       <td id="T_46479_row0_col4" class="data row0 col4" >0.503768</td>
#       <td id="T_46479_row0_col5" class="data row0 col5" >0.000055</td>
#       <td id="T_46479_row0_col6" class="data row0 col6" >0.222289</td>
#       <td id="T_46479_row0_col7" class="data row0 col7" >0.471475</td>
#       <td id="T_46479_row0_col8" class="data row0 col8" >0.496816</td>
#       <td id="T_46479_row0_col9" class="data row0 col9" >0.000073</td>
#     </tr>
#     <tr>
#       <th id="T_46479_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46479_row1_col0" class="data row1 col0" >spending_amount_small</td>
#       <td id="T_46479_row1_col1" class="data row1 col1" >0.298729</td>
#       <td id="T_46479_row1_col2" class="data row1 col2" >0.546562</td>
#       <td id="T_46479_row1_col3" class="data row1 col3" >0.000009</td>
#       <td id="T_46479_row1_col4" class="data row1 col4" >0.678489</td>
#       <td id="T_46479_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_46479_row1_col6" class="data row1 col6" >0.348776</td>
#       <td id="T_46479_row1_col7" class="data row1 col7" >0.590573</td>
#       <td id="T_46479_row1_col8" class="data row1 col8" >0.665139</td>
#       <td id="T_46479_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46479_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46479_row2_col0" class="data row2 col0" >spending_amount_medium</td>
#       <td id="T_46479_row2_col1" class="data row2 col1" >0.168846</td>
#       <td id="T_46479_row2_col2" class="data row2 col2" >0.410908</td>
#       <td id="T_46479_row2_col3" class="data row2 col3" >0.001355</td>
#       <td id="T_46479_row2_col4" class="data row2 col4" >0.643791</td>
#       <td id="T_46479_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_46479_row2_col6" class="data row2 col6" >0.192350</td>
#       <td id="T_46479_row2_col7" class="data row2 col7" >0.438577</td>
#       <td id="T_46479_row2_col8" class="data row2 col8" >0.626073</td>
#       <td id="T_46479_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46479_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46479_row3_col0" class="data row3 col0" >spending_amount_large</td>
#       <td id="T_46479_row3_col1" class="data row3 col1" >0.299506</td>
#       <td id="T_46479_row3_col2" class="data row3 col2" >0.547272</td>
#       <td id="T_46479_row3_col3" class="data row3 col3" >0.000009</td>
#       <td id="T_46479_row3_col4" class="data row3 col4" >0.697868</td>
#       <td id="T_46479_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_46479_row3_col6" class="data row3 col6" >0.321720</td>
#       <td id="T_46479_row3_col7" class="data row3 col7" >0.567204</td>
#       <td id="T_46479_row3_col8" class="data row3 col8" >0.698668</td>
#       <td id="T_46479_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46479_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46479_row4_col0" class="data

# %% [markdown]
# ### Matching 2026 candidates using closest L1 distance:
#
# (for the record, I think K clustering is probably a better approach, but I understand the code to do that exists elsewhere? And this could still be useful)

# %%
all_data_2026 = pd.read_csv("./portland_data/2026_candidate_spending_profiles_city_council.csv")

# %%
# I had code to make random data before I got the files. I'll leave it here in case it's ever useful 

# df = all_data_2026

# amount_cols = [
#     'amount_micro',
#     'amount_small',
#     'amount_medium',
#     'amount_large',
#     'amount_mega',
# ]

# share_cols = [
#     'amount_share_micro',
#     'amount_share_small',
#     'amount_share_medium',
#     'amount_share_large',
#     'amount_share_mega',
# ]

# # Generate random amounts
# np.random.seed(2026)

# df[amount_cols] = np.random.randint(
#     1000, 50000,
#     size=(len(df), len(amount_cols))
# )

# # Calculate row totals
# row_totals = df[amount_cols].sum(axis=1)

# # Calculate shares as percentages
# df[share_cols] = df[amount_cols].div(row_totals, axis=0).to_numpy() #* 100

# %%
# So L1 distance is fine as a first pass, but the problem is the units and scale are all over the place between different columns, 
# and there's really not a way to do better than to assign characteristic dollar amounts based on averages or something and then use ratios
# but essentially one way or another I have to make a decision about the relative weight given to each category, which is the same as just giving every category a fudge factor. 

# So let's do that first, and then try some other quick things (eventually a high dimensional clustering algorithm is ideal, but I think one has been implemnted already in the code I don't have)

# %%
len(independent_vars)
# Out:
# 27

# %%
all_data_2026[all_data_2026['source_candidate_name'] == "Zimmerman"]
#watch out, there's two zimmermans
# Out:
#     year  contest_type                 office  district  \
# 8   2026  city_council  Portland City Council         3
# 16  2026  city_council  Portland City Council         4
#
#                  profile_key  candidate  spending_amount_micro  \
# 8   2026|3|orestar|zimmerman  Zimmerman                  70.78
# 16  2026|4|orestar|zimmerman  Zimmerman                 388.40
#
#     spending_amount_small  spending_amount_medium  spending_amount_large  ...  \
# 8                  212.13                  884.56                5233.56  ...
# 16                2984.08                 3792.89               26446.39  ...
#
#     average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 8            225.743714               29.00             0.87           1500.0
# 16          1528.298646              156.64             0.35          50000.0
#
#     std_expenditure  source_file_stem  source_candidate_name  \
# 8        355.171968         Zimmerman              Zimmerman
# 16      5207.707704         Zimmerman              Zimmerman
#
#     canonical_candidate  candidate_key  linkage_status
# 8                   NaN            NaN     source_only
# 16                  NaN            NaN     source_only
#
# [2 rows x 38 columns]

# %%
# This function takes a list of prefactors (which are multiplied with the differences in each respective variable) 
# for each independent variable and prints the closest match and the L1 distance, and returns a dictionary of closest matches
# I had to include district # in the key becuase of repeated last names
def find_distance(fudge_factors): 
    best_match = {}
    for _, current_candidate in all_data_2026.iterrows():
        L1_distances = [0] * len(all_data)
        for i, var in enumerate(independent_vars):
            candidate_value = current_candidate[var]
            for index, old_candidate in all_data.iterrows():
                old_value = old_candidate[var]
                difference = abs(old_value - candidate_value) * fudge_factors[i]
                L1_distances[index] += difference 

        cand_index = L1_distances.index(min(L1_distances))

        print("Closet match for", current_candidate["source_candidate_name"], "is:")
        print(all_data.loc[cand_index, "source_candidate_name"])
        print("Kev check", cand_index)
        print("L1 distance:", min(L1_distances))

        best_match[current_candidate["source_candidate_name"] + " (District " + current_candidate["profile_key"][5] + ')'] = all_data.loc[cand_index, "source_candidate_name"]

    return best_match

# %%
#Fudged L1 "distances":

fudge_factors = [1] * len(independent_vars)  #determines the relative importance between all our independent variables, all 1's is not a great choice becuase dollar amount fields completely outweigh percentage fields

fudge = list(all_data[independent_vars].mean())     #I don't really know how meaningful this is, but it's better than all 1's
fudge_factors = [1/f for f in fudge]                #This just normalizes all differences by the average of the column

find_distance(fudge_factors)
# Out:
# Closet match for Corcoran is:
# trimble
# Kev check 45
# L1 distance: 6.482386727771695
# Closet match for Johnson is:
# Walker
# Kev check 36
# L1 distance: 10.9921833903988
# Closet match for Koyama is:
# Koyama
# Kev check 37
# L1 distance: 0.7974659182481101
# Closet match for Leon is:
# Salazar
# Kev check 3
# L1 distance: 7.061513455203309
# Closet match for Morillo is:
# Morillo
# Kev check 30
# L1 distance: 1.01418366813596
# Closet match for Mullen is:
# Furi
# Kev check 5
# L1 distance: 13.299877886478104
# Closet match for Novick is:
# Novick
# Kev check 32
# L1 distance: 0.0
# Closet match for Sollitt is:
# Salazar
# Kev check 3
# L1 distance: 6.6130515601641635
# Closet match for Zimmerman is:
# DiNapoli
# Kev check 43
# L1 distance: 4.4010460202776684
# Closet match for Arnold is:
# Arnold
# Kev check 47
# L1 distance: 1.1373585722747535
# Closet match for Clark is:
# Clark
# Kev check 55
# L1 distance: 0.0
# Closet match for Evenstar is:
# Linn
# Kev check 10
# L1 distance: 8.862042018458665
# Closet match for Goldsmith is:
# Sachs
# Kev check 12
# L1 distance: 6.332646573273616
# Closet match for Green is:
# Green
# Kev check 42
# L1 distance: 1.4287767318959652
# Closet match for Smith is:
# Mespelt
# Kev check 21
# L1 distance: 11.621227939460884
# Closet match for Thompson is:
# Berlin
# Kev check 29
# L1 distance: 4.157033073664604
# Closet match for Zimmerman is:
# Zimmerman
# Kev check 49
# L1 distance: 0.40931503670892844
# {'Corcoran (District 3)': 'trimble',
#  'Johnson (District 3)': 'Walker',
#  'Koyama (District 3)': 'Koyama',
#  'Leon (District 3)': 'Salazar',
#  'Morillo (District 3)': 'Morillo',
#  'Mullen (District 3)': 'Furi',
#  'Novick (District 3)': 'Novick',
#  'Sollitt (District 3)': 'Salazar',
#  'Zimmerman (District 3)': 'DiNapoli',
#  'Arnold (District 4)': 'Arnold',
#  'Clark (District 4)': 'Clark',
#  'Evenstar (District 4)': 'Linn',
#  'Goldsmith (District 4)': 'Sachs',
#  'Green (District 4)': 'Green',
#  'Smith (District 4)': 'Mespelt',
#  'Thompson (District 4)': 'Berlin',
#  'Zimmerman (District 4)': 'Zimmerman'}

# %%
# Maybe a better approach is to just consider the % of total spending in each category:  
# I'm not normalizing this vector, I think that's defensible since the space of all possible percentages is already fairly constrained 
#So this is just L1 distance between all the percentages:

fudge_factors = [0] * len(independent_vars)  #determines the relative importance between all our independent variables 
for i in range(5,10):
    fudge_factors[i] = 1

best_match = find_distance(fudge_factors)  #This is my favorite of the 3, but we'll talk about it
# Out:
# Closet match for Corcoran is:
# Furi
# Kev check 5
# L1 distance: 0.11951008275253759
# Closet match for Johnson is:
# Walker
# Kev check 36
# L1 distance: 0.5691750178372761
# Closet match for Koyama is:
# Koyama
# Kev check 37
# L1 distance: 0.0025691241229767164
# Closet match for Leon is:
# Furi
# Kev check 5
# L1 distance: 0.3711005516852576
# Closet match for Morillo is:
# Morillo
# Kev check 30
# L1 distance: 0.010286707039917053
# Closet match for Mullen is:
# Sachs
# Kev check 12
# L1 distance: 0.2363717581925297
# Closet match for Novick is:
# Novick
# Kev check 32
# L1 distance: 0.0
# Closet match for Sollitt is:
# Furi
# Kev check 5
# L1 distance: 0.2417550189934951
# Closet match for Zimmerman is:
# Mespelt
# Kev check 21
# L1 distance: 0.18757871839926338
# Closet match for Arnold is:
# Arnold
# Kev check 47
# L1 distance: 0.0354492986568723
# Closet match for Clark is:
# Clark
# Kev check 55
# L1 distance: 0.0
# Closet match for Evenstar is:
# Park
# Kev check 20
# L1 distance: 0.28503191157550606
# Closet match for Goldsmith is:
# Sachs
# Kev check 12
# L1 distance: 0.13763611628609648
# Closet match for Green is:
# Green
# Kev check 42
# L1 distance: 0.006196295012666711
# Closet match for Smith is:
# Freeman
# Kev check 51
# L1 distance: 0.08145812931094484
# Closet match for Thompson is:
# Park
# Kev check 20
# L1 distance: 0.12330548398204635
# Closet match for Zimmerman is:
# Zimmerman
# Kev check 49
# L1 distance: 0.00584091556217649

# %% [markdown]
# ### Confirming matches are reasonable:

# %%
all_data[independent_vars][all_data["source_candidate_name"] == "Furi"]
# Out:
#    spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 5                  26.25                  110.0                  283.75
#
#    spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 5                  330.0                   0.0                        0.035
#
#    spending_amount_share_small  spending_amount_share_medium  \
# 5                     0.146667                      0.378333
#
#    spending_amount_share_large  spending_amount_share_mega  ...  \
# 5                         0.44                         0.0  ...
#
#    spending_count_share_medium  spending_count_share_large  \
# 5                         0.25                       0.125
#
#    spending_count_share_mega  total_spending  expenditure_count  \
# 5                        0.0           750.0                  8
#
#    average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 5                93.75                55.0              3.5            330.0
#
#    std_expenditure
# 5       111.281577
#
# [1 rows x 27 columns]

# %%
all_data_2026[independent_vars][all_data_2026["source_candidate_name"] == "Corcoran"]
# Out:
#    spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 0                 127.68                  545.7                 1111.31
#
#    spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 0                1094.98                   0.0                     0.044338
#
#    spending_amount_share_small  spending_amount_share_medium  \
# 0                     0.189501                      0.385916
#
#    spending_amount_share_large  spending_amount_share_mega  ...  \
# 0                     0.380245                         0.0  ...
#
#    spending_count_share_medium  spending_count_share_large  \
# 0                     0.212121                    0.060606
#
#    spending_count_share_mega  total_spending  expenditure_count  \
# 0                        0.0         2879.67                 33
#
#    average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 0            87.262727               29.48              0.2            780.0
#
#    std_expenditure
# 0       148.108215
#
# [1 rows x 27 columns]

# %%
all_data[independent_vars][all_data["source_candidate_name"] == "Koyama"]
# Out:
#     spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 37                3770.17               13149.93                10910.71
#
#     spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 37               25761.45             255330.36                     0.012204
#
#     spending_amount_share_small  spending_amount_share_medium  \
# 37                     0.042567                      0.035319
#
#     spending_amount_share_large  spending_amount_share_mega  ...  \
# 37                     0.083391                    0.826519  ...
#
#     spending_count_share_medium  spending_count_share_large  \
# 37                     0.068309                    0.055991
#
#     spending_count_share_mega  total_spending  expenditure_count  \
# 37                   0.077268       308922.62                893
#
#     average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 37           345.937984               21.58             0.04          29165.0
#
#     std_expenditure
# 37      1837.290148
#
# [1 rows x 27 columns]

# %%
all_data_2026[independent_vars][all_data_2026["source_candidate_name"] == "Koyama"]
# Out:
#    spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 2                 3863.1                13297.9                11021.11
#
#    spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 2               26204.45             256810.36                     0.012414
#
#    spending_amount_share_small  spending_amount_share_medium  \
# 2                     0.042731                      0.035415
#
#    spending_amount_share_large  spending_amount_share_mega  ...  \
# 2                     0.084205                    0.825234  ...
#
#    spending_count_share_medium  spending_count_share_large  \
# 2                     0.067982                    0.055921
#
#    spending_count_share_mega  total_spending  expenditure_count  \
# 2                   0.076754       311196.92                912
#
#    average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 2           341.224693               21.53             0.04          29165.0
#
#    std_expenditure
# 2      1818.961262
#
# [1 rows x 27 columns]

# %%
#One last method: We can also do this with just the total amounts. They vary more, but at least they all have the same units.  

fudge_factors = [1,1,1,1,1] + [0] * (len(independent_vars) - 5)  #determines the relative importance between all our independent variables 

find_distance(fudge_factors)
# Out:
# Closet match for Corcoran is:
# trimble
# Kev check 45
# L1 distance: 1529.81
# Closet match for Johnson is:
# Furi
# Kev check 5
# L1 distance: 636.96
# Closet match for Koyama is:
# Koyama
# Kev check 37
# L1 distance: 2274.3000000000006
# Closet match for Leon is:
# trimble
# Kev check 45
# L1 distance: 1025.78
# Closet match for Morillo is:
# Morillo
# Kev check 30
# L1 distance: 6984.969999999999
# Closet match for Mullen is:
# trimble
# Kev check 45
# L1 distance: 874.63
# Closet match for Novick is:
# Novick
# Kev check 32
# L1 distance: 0.0
# Closet match for Sollitt is:
# trimble
# Kev check 45
# L1 distance: 1310.6999999999998
# Closet match for Zimmerman is:
# DiNapoli
# Kev check 43
# L1 distance: 1669.5900000000004
# Closet match for Arnold is:
# DePass
# Kev check 28
# L1 distance: 4041.170000000012
# Closet match for Clark is:
# Clark
# Kev check 55
# L1 distance: 0.0
# Closet match for Evenstar is:
# trimble
# Kev check 45
# L1 distance: 2236.54
# Closet match for Goldsmith is:
# Furi
# Kev check 5
# L1 distance: 419.11
# Closet match for Green is:
# Green
# Kev check 42
# L1 distance: 7911.009999999993
# Closet match for Smith is:
# Zak
# Kev check 34
# L1 distance: 13274.210000000003
# Closet match for Thompson is:
# Berlin
# Kev check 29
# L1 distance: 2860.16
# Closet match for Zimmerman is:
# Zimmerman
# Kev check 49
# L1 distance: 2337.689999999999
# {'Corcoran (District 3)': 'trimble',
#  'Johnson (District 3)': 'Furi',
#  'Koyama (District 3)': 'Koyama',
#  'Leon (District 3)': 'trimble',
#  'Morillo (District 3)': 'Morillo',
#  'Mullen (District 3)': 'trimble',
#  'Novick (District 3)': 'Novick',
#  'Sollitt (District 3)': 'trimble',
#  'Zimmerman (District 3)': 'DiNapoli',
#  'Arnold (District 4)': 'DePass',
#  'Clark (District 4)': 'Clark',
#  'Evenstar (District 4)': 'trimble',
#  'Goldsmith (District 4)': 'Furi',
#  'Green (District 4)': 'Green',
#  'Smith (District 4)': 'Zak',
#  'Thompson (District 4)': 'Berlin',
#  'Zimmerman (District 4)': 'Zimmerman'}

# %%
all_data[independent_vars][all_data["source_candidate_name"] == "trimble"]
# Out:
#     spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 45                  64.86                  275.0                   310.0
#
#     spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 45                  700.0                   0.0                     0.048049
#
#     spending_amount_share_small  spending_amount_share_medium  \
# 45                     0.203725                      0.229653
#
#     spending_amount_share_large  spending_amount_share_mega  ...  \
# 45                     0.518572                         0.0  ...
#
#     spending_count_share_medium  spending_count_share_large  \
# 45                     0.090909                    0.045455
#
#     spending_count_share_mega  total_spending  expenditure_count  \
# 45                        0.0         1349.86                 22
#
#     average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 45            61.357273               4.115              0.7            700.0
#
#     std_expenditure
# 45       150.455618
#
# [1 rows x 27 columns]

# %%
all_data_2026[independent_vars][all_data_2026["source_candidate_name"] == "Corcoran"]
# Out:
#    spending_amount_micro  spending_amount_small  spending_amount_medium  \
# 0                 127.68                  545.7                 1111.31
#
#    spending_amount_large  spending_amount_mega  spending_amount_share_micro  \
# 0                1094.98                   0.0                     0.044338
#
#    spending_amount_share_small  spending_amount_share_medium  \
# 0                     0.189501                      0.385916
#
#    spending_amount_share_large  spending_amount_share_mega  ...  \
# 0                     0.380245                         0.0  ...
#
#    spending_count_share_medium  spending_count_share_large  \
# 0                     0.212121                    0.060606
#
#    spending_count_share_mega  total_spending  expenditure_count  \
# 0                        0.0         2879.67                 33
#
#    average_expenditure  median_expenditure  min_expenditure  max_expenditure  \
# 0            87.262727               29.48              0.2            780.0
#
#    std_expenditure
# 0       148.108215
#
# [1 rows x 27 columns]

# %%
best_match  #2026 candidates are the keys, matched 2024 candidates are the outputs
# Out:
# {'Corcoran (District 3)': 'Furi',
#  'Johnson (District 3)': 'Walker',
#  'Koyama (District 3)': 'Koyama',
#  'Leon (District 3)': 'Furi',
#  'Morillo (District 3)': 'Morillo',
#  'Mullen (District 3)': 'Sachs',
#  'Novick (District 3)': 'Novick',
#  'Sollitt (District 3)': 'Furi',
#  'Zimmerman (District 3)': 'Mespelt',
#  'Arnold (District 4)': 'Arnold',
#  'Clark (District 4)': 'Clark',
#  'Evenstar (District 4)': 'Park',
#  'Goldsmith (District 4)': 'Sachs',
#  'Green (District 4)': 'Green',
#  'Smith (District 4)': 'Freeman',
#  'Thompson (District 4)': 'Park',
#  'Zimmerman (District 4)': 'Zimmerman'}

# %% [markdown]
# ### It would be nice to see how we did, but we don't have 2026 FPV or mentions data yet obviously...

# %%
# #that said, I wrote most of the code before I realized we just didn't have the data, so I'll leave it here. Sue me, it's 2am. 

# performance_comparison = {}
# for key in best_match.keys():
#     lastname = key.split()[0]
#     dist = key[-2]
#     print(lastname, dist)

#     mentions_2026 = all_data_2026.loc[
#         (all_data_2026["source_candidate_name"] == lastname)
#         & (all_data_2026["district"] == int(dist)),
#         independent_vars
#     ][['mentions', 'mention_share', 'first_place_votes', 'first_place_share']]

#     mentions_2026["year"] = 2026

#     mentions_2024 = all_data.loc[all_data["source_candidate_name"] == best_match[key]][['mentions', 'mention_share', 'first_place_votes', 'first_place_share']]

#     mentions_2024["year"] = 2024

#     performance_comparison[key] = pd.concat([mentions_2024, mentions_2026], ignore_index=True)

# performance_comparison

# %% [markdown]
# ### Lastly (for now), let's go deeper into transaction type:

# %% [markdown]
# ### How candidates spent money

# %%
transaction_file = pd.read_csv('./portland_data/transactions_2024.csv')
transaction_file = transaction_file[['filer','amount','sub_type',
       'aggregate_amount', 'counterparty_committee_id', 'filer_id',
       'attest_by_name', 'attest_date', 'review_by_name', 'review_date',
       'due_date', 'occptn_ltr_date', 'pymt_sched_txt', 'purpose_description',
       'intrst_rate', 'check_nbr', 'tran_stsfd_ind', 'filed_by_name',
       'filed_date', 'addr_book_agent_name', 'book_type', 'title_txt',
       'occptn_txt', 'purpose_codes', 'expenditure_date', 'source_file_stem','is_reported_expenditure', 'reported_expenditure_amount']]
# Out:
# /tmp/ipykernel_2617463/3690611237.py:1: DtypeWarning: Columns (0: occptn_ltr_date, 1: foreign_postal_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   transaction_file = pd.read_csv('./portland_data/transactions_2024.csv')

# %%
# D1_names = ['Avalos', 'Rouph', 'Dunphy', 'Smith','Hayes','Ender','Ernst']  

all_names = list(set(transaction_file['source_file_stem']))  #this should be a list of everybody 
exp_dict = {}
for name in all_names:
    candidate_expenditures = transaction_file[(transaction_file['source_file_stem'] == name) & (transaction_file['sub_type'] == "Cash Expenditure")
    ]
    exp_dict[name] = candidate_expenditures[['amount', 'purpose_codes', 'reported_expenditure_amount']] \
    .groupby("purpose_codes") \
    .sum() \
    .sort_values("amount", ascending=False)

# %%
#So what I've done here is build a dictionary for each candidate with a breakdown of how they spent their money

exp_dict['Avalos']
# Out:
#                                                       amount  \
# purpose_codes
# Wages, Salaries, Benefits                           43313.88
# Literature, Brochures, Printing                     42180.59
# General Operational Expenses (need description)     26707.37
# Online and Social Media Advertising                 18000.91
# Management Services                                 12400.89
# Other Advertising (yard signs, buttons, etc.)        7408.68
# Management Services; Postage                         6757.94
# General Operational Expenses (need description)...   6148.86
# Postage; Literature, Brochures, Printing             3186.44
# Reimbursement for Personal Expenditures              1737.85
# Postage                                              1318.55
# General Operational Expenses (need description)...   1262.16
# General Operational Expenses (need description)...    919.00
# Fundraising Event Expenses                            800.00
# Preparation and Production of Advertising             400.00
# Cash Contribution                                     250.00
#
#                                                     reported_expenditure_amount
# purpose_codes
# Wages, Salaries, Benefits                                              43313.88
# Literature, Brochures, Printing                                        42180.59
# General Operational Expenses (need description)                        26707.37
# Online and Social Media Advertising                                    18000.91
# Management Services                                                    12400.89
# Other Advertising (yard signs, buttons, etc.)                           7408.68
# Management Services; Postage                                            6757.94
# General Operational Expenses (need description)...                      6148.86
# Postage; Literature, Brochures, Printing                                3186.44
# Reimbursement for Personal Expenditures                                 1737.85
# Postage                                                                 1318.55
# General Operational Expenses (need description)...                      1262.16
# General Operational Expenses (need description)...                       919.00
# Fundraising Event Expenses                                               800.00
# Preparation and Production of Advertising                                400.00
# Cash Contribution                                                        250.00

# %%
exp_dict['Kanal']
#confirmed that Kanal is still a problem here
# Out:
# Empty DataFrame
# Columns: [amount, reported_expenditure_amount]
# Index: []

# %%
transaction_file[(transaction_file['source_file_stem'] == 'Kanal') & (transaction_file['sub_type'] == "Cash Expenditure")][['amount','purpose_codes']]
# Out:
#        amount purpose_codes
# 10459   32.00           NaN
# 10460   52.80           NaN
# 10461   35.00           NaN
# 10462    4.99           NaN
# 10463   35.00           NaN
# ...       ...           ...
# 10737  972.00           NaN
# 10738   77.17           NaN
# 10746   19.75           NaN
# 10752   35.57           NaN
# 10761   60.96           NaN
#
# [166 rows x 2 columns]

# %%
# my_list = list(all_data['candidate_key'])
# my_list.sort()
# my_list
# #Important check: there are no other smiths in this data file, so all that spending really was for loretta smith (or there was a typo somewhere)
